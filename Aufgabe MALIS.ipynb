# %%
import pandas as pd

# %%
# Datei hier anzeigen lassen:

# %%
pd.read_excel('Statistik.xlsx')
# Out:
#    Systematik  Anzahl  Ausl. Ges.  JAHR   VJAHR   VVJAHR   VVVJAHR   VVVVJAHR
# 0      Summe:     271        9482   247     244      360       447        528
# 1          Oa       2           9     0       9        0         0          0
# 2         Oal       3           0     0       0        0         0          0
# 3       Oal 1       4         173     0       0        0         4          0
# 4         Obl       1           4     0       0        0         0          1
# 5         Ocm       2          89     1       1        0         3          0
# 6         Ocn       5         113     0       2        4        14         12
# 7       Oem 2       2          68     0       0        1         3          7
# 8       Oem 5       1          29     0       0        0         0          0
# 9       Ofk 2      21        2007    10      16       18        72         51
# 10     Ofk 21       1          44     0       0        0         0          0
# ...

# %%
# Name geben: "Statistikliste"

# %%
Statistikliste = pd.read_excel('Statistik.xlsx')

# %%
# Die ersten fünf Zeilen werden ausgegeben.

# %%
Statistikliste.head()
# Out:
#   Systematik  Anzahl  Ausl. Ges.  JAHR   VJAHR   VVJAHR   VVVJAHR   VVVVJAHR
# 0     Summe:     271        9482   247     244      360       447        528
# 1         Oa       2           9     0       9        0         0          0
# 2        Oal       3           0     0       0        0         0          0
# 3      Oal 1       4         173     0       0        0         4          0
# 4        Obl       1           4     0       0        0         0          1

# %%
# Wie viele Zeilen und Spalten gibt es insgesamt?

# %%
Statistikliste.shape
# Out:
# (51, 8)

# %%
# Wie sind die Spalten benannt?

# %%
Statistikliste.columns
# Out:
# Index(['Systematik', 'Anzahl', 'Ausl. Ges.', 'JAHR', ' VJAHR', ' VVJAHR',
#        ' VVVJAHR', ' VVVVJAHR'],
#       dtype='object')

# %%
# Welche Ergebnisse werden unter Systematik angezeigt?

# %%
Statistikliste["Systematik"]
# Out:
# 0     Summe:
# 1         Oa
# 2        Oal
# 3      Oal 1
# 4        Obl
# 5        Ocm
# 6        Ocn
# 7      Oem 2
# 8      Oem 5
# 9      Ofk 2
# 10    Ofk 21
# 11     Ofk 4
# 12     Ofk 5
# 13    Ofk 51
# 14     Ofk 6
# 15    Ofk 61
# 16       Ofl
# 17     Ofm 2
# 18    Ofm 21
# 19     Ofm 5
# 20    Ofm 51
# 21     Ofm 6
# 22     Ofn 2
# 23     Ofn 4
# 24     Ofn 5
# 25    Ofn 51
# 26     Ofn 6
# 27     Ofo 2
# 28    Ofo 21
# 29     Ofo 4
# 30     Ofo 5
# 31    Ofo 51
# 32     Ofo 6
# 33       Ofp
# 34     Ofq 2
# 35    Ofq 21
# 36     Ofq 5
# 37       Ofr
# 38       Ofs
# 39     Ogk 2
# 40     Ogk 3
# 41       Ogl
# 42       Ogn
# 43       Ogo
# 44       Ogr
# 45       Ogt
# 46     Ogt 1
# 47     Ogt 4
# 48     Ogt 5
# 49    Ogt 51
# 50       Ogv
# Name: Systematik, dtype: object

# %%
# Welches ist der höchste Wert bei "Ausleihe Gesamt"?

# %%
Statistikliste["Ausl. Ges."].max()
# Out:
# 9482

# %%
# Da dieser Wert aus der allerersten Zeilen stammt und sich auf
# alles bezieht, ist er nicht so sinnvoll. Eine bessere Möglichkeit
# ist es, zu schauen, welche Systematikstellen die höchsten Ausleih-
# zahlen haben.

# %%
Statistikliste[Statistikliste["Ausl. Ges."] >= 100]
# Out:
#    Systematik  Anzahl  Ausl. Ges.  JAHR   VJAHR   VVJAHR   VVVJAHR   VVVVJAHR
# 0      Summe:     271        9482   247     244      360       447        528
# 3       Oal 1       4         173     0       0        0         4          0
# 6         Ocn       5         113     0       2        4        14         12
# 9       Ofk 2      21        2007    10      16       18        72         51
# 12      Ofk 5       6         277     4       0       28        14         27
# 16        Ofl      16         714    26      48       36        49         61
# 17      Ofm 2      10         535    13       4       31        12         20
# 19      Ofm 5       8         334     3       0        3        15         23
# 22      Ofn 2      10         475    21      17       21        41         27
# 24      Ofn 5       3         259    10      11        7         4         10
# 27      Ofo 2      18        1283    55      40       39        65         34
# ...

# %%
# Jetzt möchten wir jedoch nicht nur wissen, welche Systematik-
# stellen über die gesamte Zeit die höchsten Ausleihzahlen hatten,
# sondern welche auch aktuell gut gehen. Dafür habe ich verschiedene
# Werte ausprobiert und diese übrig gelassen:

# %%
Statistikliste[Statistikliste["JAHR"] >= 50]
# Out:
#    Systematik  Anzahl  Ausl. Ges.  JAHR   VJAHR   VVJAHR   VVVJAHR   VVVVJAHR
# 0      Summe:     271        9482   247     244      360       447        528
# 27      Ofo 2      18        1283    55      40       39        65         34

# %%
Statistikliste[Statistikliste["JAHR"] >= 30]
# Out:
#    Systematik  Anzahl  Ausl. Ges.  JAHR   VJAHR   VVJAHR   VVVJAHR   VVVVJAHR
# 0      Summe:     271        9482   247     244      360       447        528
# 27      Ofo 2      18        1283    55      40       39        65         34
# 45        Ogt      39         916    30       9       66        63        110

# %%
Statistikliste[Statistikliste["JAHR"] >= 20]
# Out:
#    Systematik  Anzahl  Ausl. Ges.  JAHR   VJAHR   VVJAHR   VVVJAHR   VVVVJAHR
# 0      Summe:     271        9482   247     244      360       447        528
# 16        Ofl      16         714    26      48       36        49         61
# 22      Ofn 2      10         475    21      17       21        41         27
# 27      Ofo 2      18        1283    55      40       39        65         34
# 38        Ofs      17         537    22      27       19        15         41
# 45        Ogt      39         916    30       9       66        63        110

# %%
Statistikliste[Statistikliste["JAHR"] >= 10]
# Out:
#    Systematik  Anzahl  Ausl. Ges.  JAHR   VJAHR   VVJAHR   VVVJAHR   VVVVJAHR
# 0      Summe:     271        9482   247     244      360       447        528
# 9       Ofk 2      21        2007    10      16       18        72         51
# 16        Ofl      16         714    26      48       36        49         61
# 17      Ofm 2      10         535    13       4       31        12         20
# 22      Ofn 2      10         475    21      17       21        41         27
# 24      Ofn 5       3         259    10      11        7         4         10
# 27      Ofo 2      18        1283    55      40       39        65         34
# 38        Ofs      17         537    22      27       19        15         41
# 45        Ogt      39         916    30       9       66        63        110

# %%
# Also kann festgestellt werden, dass diese Systematikstellen
# (Ofk 2, Ofl, Ofm 2, Ofn 2, Ofn 5, Ofo 2, Ofs und Ogt) hohe
# Ausleihzahlen generieren.

# %%
# Um eine grafische Übersicht zu generieren, die anzeigt, welche
# Verteilung die Werte haben, kann folgender Code genutzt werden:

# %%
Statistikliste["JAHR"].hist()
# Out:
# <AxesSubplot:>

# %%
# Wenn man die Farbe ändern möchte, kann folgender Code angewendet
# werden:

# %%
Statistikliste["JAHR"].hist(color="#eb135c")
# Out:
# <AxesSubplot:>

# %%
# fun fact: Dies ist auch die Farbe vom Logo der Stadtbibliothek
# Achim.

# %%
Statistik_JAHR = Statistikliste[["Systematik", "JAHR"]]

# %%
# Hiermit wurde die vereinfachte Ansicht, in der nur die Systematik
# und das Jahr auftauchen definiert. Und wenn man diese Definition
# jetzt eingibt, bekommt man folgendes Ergebnis:

# %%
Statistik_JAHR
# Out:
#    Systematik  JAHR
# 0      Summe:   247
# 1          Oa     0
# 2         Oal     0
# 3       Oal 1     0
# 4         Obl     0
# 5         Ocm     1
# 6         Ocn     0
# 7       Oem 2     0
# 8       Oem 5     0
# 9       Ofk 2    10
# 10     Ofk 21     0
# 11      Ofk 4     0
# 12      Ofk 5     4
# 13     Ofk 51     0
# 14      Ofk 6     2
# 15     Ofk 61     0
# 16        Ofl    26
# 17      Ofm 2    13
# 18     Ofm 21     7
# 19      Ofm 5     3
# 20     Ofm 51     2
# 21      Ofm 6     3
# 22      Ofn 2    21
# 23      Ofn 4     1
# 24      Ofn 5    10
# 25     Ofn 51     2
# 26      Ofn 6     0
# 27      Ofo 2    55
# 28     Ofo 21     4
# 29      Ofo 4     5
# 30      Ofo 5     0
# 31     Ofo 51     3
# 32      Ofo 6     0
# 33        Ofp     0
# 34      Ofq 2     0
# 35     Ofq 21     2
# 36      Ofq 5     2
# 37        Ofr     4
# 38        Ofs    22
# 39      Ogk 2     0
# 40      Ogk 3     0
# 41        Ogl     0
# 42        Ogn     1
# 43        Ogo     0
# ...

# %%
Statistik_JAHR.groupby("Systematik").sum().sort_values(by="JAHR", ascending=False)
# Out:
#             JAHR
# Systematik
# Summe:       247
# Ofo 2         55
# Ogt           30
# Ofl           26
# Ofs           22
# Ofn 2         21
# Ofm 2         13
# Ofn 5         10
# Ofk 2         10
# Ofm 21         7
# Ogt 5          7
# Ogr            5
# Ofo 4          5
# Ofr            4
# Ofo 21         4
# Ofk 5          4
# Ofm 6          3
# Ofo 51         3
# Ofm 5          3
# Ofn 51         2
# Ofq 21         2
# Ofm 51         2
# Ofq 5          2
# Ofk 6          2
# Ocm            1
# Ogt 4          1
# Ogn            1
# Ogv            1
# Ofn 4          1
# Ogl            0
# Ogt 51         0
# Ogt 1          0
# Ogk 3          0
# Ogk 2          0
# Ogo            0
# Oa             0
# Ofq 2          0
# Ofp            0
# Ofo 6          0
# Ofo 5          0
# Oal            0
# Ofk 61         0
# Ofk 51         0
# Ofk 4          0
# Ofk 21         0
# Oem 5          0
# Oem 2          0
# Ocn            0
# Obl            0
# Oal 1          0
# ...

# %%
Statistik_JAHR.groupby("Systematik").sum().sort_values(by="JAHR", ascending=False).plot.barh()
# Out:
# <AxesSubplot:ylabel='Systematik'>

# %%
# Die 0er würde ich jetzt gerne noch ausschließen.

# %%
Statistik_JAHR.groupby("Systematik").sum().sort_values(by="JAHR", ascending=False).head(20)
# Out:
#             JAHR
# Systematik
# Summe:       247
# Ofo 2         55
# Ogt           30
# Ofl           26
# Ofs           22
# Ofn 2         21
# Ofm 2         13
# Ofn 5         10
# Ofk 2         10
# Ofm 21         7
# Ogt 5          7
# Ogr            5
# Ofo 4          5
# Ofr            4
# Ofo 21         4
# Ofk 5          4
# Ofm 6          3
# Ofo 51         3
# Ofm 5          3
# Ofn 51         2

# %%
Statistik_JAHR.groupby("Systematik").sum().sort_values(by="JAHR", ascending=False).head(30)
# Out:
#             JAHR
# Systematik
# Summe:       247
# Ofo 2         55
# Ogt           30
# Ofl           26
# Ofs           22
# Ofn 2         21
# Ofm 2         13
# Ofn 5         10
# Ofk 2         10
# Ofm 21         7
# Ogt 5          7
# Ogr            5
# Ofo 4          5
# Ofr            4
# Ofo 21         4
# Ofk 5          4
# Ofm 6          3
# Ofo 51         3
# Ofm 5          3
# Ofn 51         2
# Ofq 21         2
# Ofm 51         2
# Ofq 5          2
# Ofk 6          2
# Ocm            1
# Ogt 4          1
# Ogn            1
# Ogv            1
# Ofn 4          1
# Ogl            0

# %%
Statistik_JAHR.groupby("Systematik").sum().sort_values(by="JAHR", ascending=False).head(30).plot.bar()
# Out:
# <AxesSubplot:xlabel='Systematik'>

# %%
# Jetzt würde ich gerne noch die "Summe" ausschließen, weil es ja 
# die Gesamtsumme ist und unverhältnismäßig zum Rest ist.

# %%
Statistik_JAHR.groupby("Systematik").sum().sort_values(by="JAHR", ascending=False).tail(30).plot.bar()
# Out:
# <AxesSubplot:xlabel='Systematik'>

# %%
# Mit tail habe ich wieder das Problem, dass die ganzen 0er
# angezeigt werden. Ich brauche also einen Befehl, mit dem ich die
# erste Zeile auslassen kann.

# %%
Statistik_JAHR.groupby("Systematik").sum().sort_values(by="JAHR", ascending=False).head(30).plot.bar()[2:30]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [200], in <cell line: 1>()
# ----> 1 Statistik_JAHR.groupby("Systematik").sum().sort_values(by="JAHR", ascending=False).head(30).plot.bar()[2:30]
#
# TypeError: 'AxesSubplot' object is not subscriptable

# %%
# Slicing funktioniert so nicht...

# %%
Statistik_JAHR.groupby("Systematik").sum().sort_values(by="JAHR", ascending=False).slice(2:30).plot.bar()
# Out:
#   Input In [202]
#     Statistik_JAHR.groupby("Systematik").sum().sort_values(by="JAHR", ascending=False).slice(2:30).plot.bar()
#                                                                                               ^
# SyntaxError: invalid syntax

# %%
# So auch nicht...

# %%
Statistik_JAHR.groupby("Systematik").sum().sort_values(by="JAHR", ascending=False).slice2[2:30].plot.bar()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [204], in <cell line: 1>()
# ----> 1 Statistik_JAHR.groupby("Systematik").sum().sort_values(by="JAHR", ascending=False).slice2[2:30].plot.bar()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'slice2'

# %%
# hmmm

# %%
Statistik_JAHR.groupby("Systematik").sum().sort_values(by="JAHR", ascending=False).head(30).plot.bar().slice[2:30]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [206], in <cell line: 1>()
# ----> 1 Statistik_JAHR.groupby("Systematik").sum().sort_values(by="JAHR", ascending=False).head(30).plot.bar().slice[2:30]
#
# AttributeError: 'AxesSubplot' object has no attribute 'slice'

# %%
print(Statistik_JAHR[2:30])
# Out:
#    Systematik  JAHR
# 2         Oal     0
# 3       Oal 1     0
# 4         Obl     0
# 5         Ocm     1
# 6         Ocn     0
# 7       Oem 2     0
# 8       Oem 5     0
# 9       Ofk 2    10
# 10     Ofk 21     0
# 11      Ofk 4     0
# 12      Ofk 5     4
# 13     Ofk 51     0
# 14      Ofk 6     2
# 15     Ofk 61     0
# 16        Ofl    26
# 17      Ofm 2    13
# 18     Ofm 21     7
# 19      Ofm 5     3
# 20     Ofm 51     2
# 21      Ofm 6     3
# 22      Ofn 2    21
# 23      Ofn 4     1
# 24      Ofn 5    10
# 25     Ofn 51     2
# 26      Ofn 6     0
# 27      Ofo 2    55
# 28     Ofo 21     4
# 29      Ofo 4     5

# %%
# So ist es schonmal ein Teil der Lösung.

# %%
StaJa = Statistik_JAHR.groupby("Systematik").sum().sort_values(by="JAHR", ascending=False).head(30).plot.bar()

# %%
print(StaJa[2:30])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [210], in <cell line: 1>()
# ----> 1 print(StaJa[2:30])
#
# TypeError: 'AxesSubplot' object is not subscriptable

# %%
print(StaJa)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
# Völlig auf dem falschen Dampfer.

# %%
Statistik_JAHR.groupby("Systematik").sum().sort_values(by="JAHR", ascending=False).head(30).plot.bar()
# Out:
# <AxesSubplot:xlabel='Systematik'>

# %%
# Stack Overflow war sehr hilfreich bei der Suche nach der Lösung. Dazu musste ich jedoch erstmal wissen, welchen
# Suchbegriff ich eigentlich genau eingeben musste (jupyter notebook remove first line head). Daraufhin bin ich
# auf den folgenden Artikel gestoßen: Delete the first three rows of a dataframe in pandas

# %%
Staja = Statistik_JAHR.iloc[1:]

# %%
# Zur Überprüfung habe ich es einmal mit print anzeigen lassen.

# %%
print(Staja)
# Out:
#    Systematik  JAHR
# 1          Oa     0
# 2         Oal     0
# 3       Oal 1     0
# 4         Obl     0
# 5         Ocm     1
# 6         Ocn     0
# 7       Oem 2     0
# 8       Oem 5     0
# 9       Ofk 2    10
# 10     Ofk 21     0
# 11      Ofk 4     0
# 12      Ofk 5     4
# 13     Ofk 51     0
# 14      Ofk 6     2
# 15     Ofk 61     0
# 16        Ofl    26
# 17      Ofm 2    13
# 18     Ofm 21     7
# 19      Ofm 5     3
# 20     Ofm 51     2
# 21      Ofm 6     3
# 22      Ofn 2    21
# 23      Ofn 4     1
# 24      Ofn 5    10
# 25     Ofn 51     2
# 26      Ofn 6     0
# 27      Ofo 2    55
# 28     Ofo 21     4
# 29      Ofo 4     5
# 30      Ofo 5     0
# 31     Ofo 51     3
# 32      Ofo 6     0
# 33        Ofp     0
# 34      Ofq 2     0
# 35     Ofq 21     2
# 36      Ofq 5     2
# 37        Ofr     4
# 38        Ofs    22
# 39      Ogk 2     0
# 40      Ogk 3     0
# 41        Ogl     0
# 42        Ogn     1
# 43        Ogo     0
# 44        Ogr     5
# ...

# %%
Staja.groupby("Systematik").sum().sort_values(by="JAHR", ascending=False).head(28).plot.bar()
# Out:
# <AxesSubplot:xlabel='Systematik'>

# %%
# Jetzt habe ich eine grafische Auflistung aller Systematikstellen, die mindestens eine Ausleihe in diesem Jahr
# hatten.
